# %% [markdown]
# 1.Write a Python Program to Check if a Number is Positive, Negative or Zero

# %%
s=int(input("Enter no."))
if(s==0):
    print("zero")
elif(s>0):
    print("Positive")
else:
    print("Negative")
# Out:
# Enter no.-4
# Negative

# %% [markdown]
# 2.Write a Python Program to Check if a Number is Odd or Even?

# %%
s=int(input("Enter no."))
if(s%2==0):
    print("even")
elif s==0:
    print("Zero")
else:
    print("odd")
# Out:
# Enter no.3
# odd

# %% [markdown]
# 3.Write a Python Program to Check Leap Year?

# %%
year=int(input("Enter the year- "))
if (year % 4) == 0:
   if (year % 100) == 0:
       if (year % 400) == 0:
           print("{0} is a leap year".format(year))
       else:
           print("{0} is not a leap year".format(year))
   else:
       print("{0} is a leap year".format(year))
else:
   print("{0} is not a leap year".format(year))
# Out:
# Enter the year- 2016
# 2016 is a leap year

# %% [markdown]
# Write a Python Program to Check Prime Number?

# %%
s=int(input("Enter no."))
flag=0
for i in range(2,s):
    if(s%i==0):
        flag+=1
if flag==0:
    print("Prime")
else:
    print("Not prime")
# Out:
# Enter no.3
# Prime

# %% [markdown]
# Write a Python Program to Print all Prime Numbers in an Interval of 1-1000

# %%
for i in range(2,1000):
    flag=0
    for j in range(2,i):
        if(i%j==0):
            flag+=1
            break
    if flag==0:
        print(f"{i} is Prime")
    else:
        print(f"{i} is Not prime")
# Out:
# 2 is Prime
# 3 is Prime
# 4 is Not prime
# 5 is Prime
# 6 is Not prime
# 7 is Prime
# 8 is Not prime
# 9 is Not prime
# 10 is Not prime
# 11 is Prime
# 12 is Not prime
# 13 is Prime
# 14 is Not prime
# 15 is Not prime
# 16 is Not prime
# 17 is Prime
# 18 is Not prime
# 19 is Prime
# 20 is Not prime
# 21 is Not prime
# 22 is Not prime
# 23 is Prime
# 24 is Not prime
# 25 is Not prime
# 26 is Not prime
# 27 is Not prime
# 28 is Not prime
# 29 is Prime
# 30 is Not prime
# 31 is Prime
# 32 is Not prime
# 33 is Not prime
# 34 is Not prime
# 35 is Not prime
# 36 is Not prime
# 37 is Prime
# 38 is Not prime
# 39 is Not prime
# 40 is Not prime
# 41 is Prime
# 42 is Not prime
# 43 is Prime
# 44 is Not prime
# 45 is Not prime
# 46 is Not prime
# 47 is Prime
# 48 is Not prime
# 49 is Not prime
# 50 is Not prime
# 51 is Not prime
# 52 is Not prime
# 53 is Prime
# 54 is Not prime
# 55 is Not prime
# 56 is Not prime
# 57 is Not prime
# 58 is Not prime
# 59 is Prime
# 60 is Not prime
# 61 is Prime
# 62 is Not prime
# 63 is Not prime
# 64 is Not prime
# 65 is Not prime
# 66 is Not prime
# 67 is Prime
# 68 is Not prime
# 69 is Not prime
# 70 is Not prime
# 71 is Prime
# 72 is Not prime
# 73 is Prime
# 74 is Not prime
# 75 is Not prime
# 76 is Not prime
# 77 is Not prime
# 78 is Not prime
# 79 is Prime
# 80 is Not prime
# 81 is Not prime
# 82 is Not prime
# 83 is Prime
# 84 is Not prime
# 85 is Not prime
# 86 is Not prime
# 87 is Not prime
# 88 is Not prime
# 89 is Prime
# 90 is Not prime
# 91 is Not prime
# 92 is Not prime
# 93 is Not prime
# 94 is Not prime
# 95 is Not prime
# 96 is Not prime
# 97 is Prime
# 98 is Not prime
# 99 is Not prime
# 100 is Not prime
# 101 is Prime
# 102 is Not prime
# 103 is Prime
# 104 is Not prime
# 105 is Not prime
# 106 is Not prime
# 107 is Prime
# 108 is Not prime
# 109 is Prime
# 110 is Not prime
# 111 is Not prime
# 112 is Not prime
# 113 is Prime
# 114 is Not prime
# 115 is Not prime
# 116 is Not prime
# 117 is Not prime
# 118 is Not prime
# 119 is Not prime
# 120 is Not prime
# 121 is Not prime
# 122 is Not prime
# 123 is Not prime
# 124 is Not prime
# 125 is Not prime
# 126 is Not prime
# 127 is Prime
# 128 is Not prime
# 129 is Not prime
# 130 is Not prime
# 131 is Prime
# 132 is Not prime
# 133 is Not prime
# 134 is Not prime
# 135 is Not prime
# 136 is Not prime
# 137 is Prime
# 138 is Not prime
# 139 is Prime
# 140 is Not prime
# 141 is Not prime
# 142 is Not prime
# 143 is Not prime
# 144 is Not prime
# 145 is Not prime
# 146 is Not prime
# 147 is Not prime
# 148 is Not prime
# 149 is Prime
# 150 is Not prime
# 151 is Prime
# 152 is Not prime
# 153 is Not prime
# 154 is Not prime
# 155 is Not prime
# 156 is Not prime
# 157 is Prime
# 158 is Not prime
# 159 is Not prime
# 160 is Not prime
# 161 is Not prime
# 162 is Not prime
# 163 is Prime
# 164 is Not prime
# 165 is Not prime
# 166 is Not prime
# 167 is Prime
# 168 is Not prime
# 169 is Not prime
# 170 is Not prime
# 171 is Not prime
# 172 is Not prime
# 173 is Prime
# 174 is Not prime
# 175 is Not prime
# 176 is Not prime
# 177 is Not prime
# 178 is Not prime
# 179 is Prime
# 180 is Not prime
# 181 is Prime
# 182 is Not prime
# 183 is Not prime
# 184 is Not prime
# 185 is Not prime
# 186 is Not prime
# 187 is Not prime
# 188 is Not prime
# 189 is Not prime
# 190 is Not prime
# 191 is Prime
# 192 is Not prime
# 193 is Prime
# 194 is Not prime
# 195 is Not prime
# 196 is Not prime
# 197 is Prime
# 198 is Not prime
# 199 is Prime
# 200 is Not prime
# 201 is Not prime
# 202 is Not prime
# 203 is Not prime
# 204 is Not prime
# 205 is Not prime
# 206 is Not prime
# 207 is Not prime
# 208 is Not prime
# 209 is Not prime
# 210 is Not prime
# 211 is Prime
# 212 is Not prime
# 213 is Not prime
# 214 is Not prime
# 215 is Not prime
# 216 is Not prime
# 217 is Not prime
# 218 is Not prime
# 219 is Not prime
# 220 is Not prime
# 221 is Not prime
# 222 is Not prime
# 223 is Prime
# 224 is Not prime
# 225 is Not prime
# 226 is Not prime
# 227 is Prime
# 228 is Not prime
# 229 is Prime
# 230 is Not prime
# 231 is Not prime
# 232 is Not prime
# 233 is Prime
# 234 is Not prime
# 235 is Not prime
# 236 is Not prime
# 237 is Not prime
# 238 is Not prime
# 239 is Prime
# 240 is Not prime
# 241 is Prime
# 242 is Not prime
# 243 is Not prime
# 244 is Not prime
# 245 is Not prime
# 246 is Not prime
# 247 is Not prime
# 248 is Not prime
# 249 is Not prime
# 250 is Not prime
# 251 is Prime
# 252 is Not prime
# 253 is Not prime
# 254 is Not prime
# 255 is Not prime
# 256 is Not prime
# 257 is Prime
# 258 is Not prime
# 259 is Not prime
# 260 is Not prime
# 261 is Not prime
# 262 is Not prime
# 263 is Prime
# 264 is Not prime
# 265 is Not prime
# 266 is Not prime
# 267 is Not prime
# 268 is Not prime
# 269 is Prime
# 270 is Not prime
# 271 is Prime
# 272 is Not prime
# 273 is Not prime
# 274 is Not prime
# 275 is Not prime
# 276 is Not prime
# 277 is Prime
# 278 is Not prime
# 279 is Not prime
# 280 is Not prime
# 281 is Prime
# 282 is Not prime
# 283 is Prime
# 284 is Not prime
# 285 is Not prime
# 286 is Not prime
# 287 is Not prime
# 288 is Not prime
# 289 is Not prime
# 290 is Not prime
# 291 is Not prime
# 292 is Not prime
# 293 is Prime
# 294 is Not prime
# 295 is Not prime
# 296 is Not prime
# 297 is Not prime
# 298 is Not prime
# 299 is Not prime
# 300 is Not prime
# 301 is Not prime
# 302 is Not prime
# 303 is Not prime
# 304 is Not prime
# 305 is Not prime
# 306 is Not prime
# 307 is Prime
# 308 is Not prime
# 309 is Not prime
# 310 is Not prime
# 311 is Prime
# 312 is Not prime
# 313 is Prime
# 314 is Not prime
# 315 is Not prime
# 316 is Not prime
# 317 is Prime
# 318 is Not prime
# 319 is Not prime
# 320 is Not prime
# 321 is Not prime
# 322 is Not prime
# 323 is Not prime
# 324 is Not prime
# 325 is Not prime
# 326 is Not prime
# 327 is Not prime
# 328 is Not prime
# 329 is Not prime
# 330 is Not prime
# 331 is Prime
# 332 is Not prime
# 333 is Not prime
# 334 is Not prime
# 335 is Not prime
# 336 is Not prime
# 337 is Prime
# 338 is Not prime
# 339 is Not prime
# 340 is Not prime
# 341 is Not prime
# 342 is Not prime
# 343 is Not prime
# 344 is Not prime
# 345 is Not prime
# 346 is Not prime
# 347 is Prime
# 348 is Not prime
# 349 is Prime
# 350 is Not prime
# 351 is Not prime
# 352 is Not prime
# 353 is Prime
# 354 is Not prime
# 355 is Not prime
# 356 is Not prime
# 357 is Not prime
# 358 is Not prime
# 359 is Prime
# 360 is Not prime
# 361 is Not prime
# 362 is Not prime
# 363 is Not prime
# 364 is Not prime
# 365 is Not prime
# 366 is Not prime
# 367 is Prime
# 368 is Not prime
# 369 is Not prime
# 370 is Not prime
# 371 is Not prime
# 372 is Not prime
# 373 is Prime
# 374 is Not prime
# 375 is Not prime
# 376 is Not prime
# 377 is Not prime
# 378 is Not prime
# 379 is Prime
# 380 is Not prime
# 381 is Not prime
# 382 is Not prime
# 383 is Prime
# 384 is Not prime
# 385 is Not prime
# 386 is Not prime
# 387 is Not prime
# 388 is Not prime
# 389 is Prime
# 390 is Not prime
# 391 is Not prime
# 392 is Not prime
# 393 is Not prime
# 394 is Not prime
# 395 is Not prime
# 396 is Not prime
# 397 is Prime
# 398 is Not prime
# 399 is Not prime
# 400 is Not prime
# 401 is Prime
# 402 is Not prime
# 403 is Not prime
# 404 is Not prime
# 405 is Not prime
# 406 is Not prime
# 407 is Not prime
# 408 is Not prime
# 409 is Prime
# 410 is Not prime
# 411 is Not prime
# 412 is Not prime
# 413 is Not prime
# 414 is Not prime
# 415 is Not prime
# 416 is Not prime
# 417 is Not prime
# 418 is Not prime
# 419 is Prime
# 420 is Not prime
# 421 is Prime
# 422 is Not prime
# 423 is Not prime
# 424 is Not prime
# 425 is Not prime
# 426 is Not prime
# 427 is Not prime
# 428 is Not prime
# 429 is Not prime
# 430 is Not prime
# 431 is Prime
# 432 is Not prime
# 433 is Prime
# 434 is Not prime
# 435 is Not prime
# 436 is Not prime
# 437 is Not prime
# 438 is Not prime
# 439 is Prime
# 440 is Not prime
# 441 is Not prime
# 442 is Not prime
# 443 is Prime
# 444 is Not prime
# 445 is Not prime
# 446 is Not prime
# 447 is Not prime
# 448 is Not prime
# 449 is Prime
# 450 is Not prime
# 451 is Not prime
# 452 is Not prime
# 453 is Not prime
# 454 is Not prime
# 455 is Not prime
# 456 is Not prime
# 457 is Prime
# 458 is Not prime
# 459 is Not prime
# 460 is Not prime
# 461 is Prime
# 462 is Not prime
# 463 is Prime
# 464 is Not prime
# 465 is Not prime
# 466 is Not prime
# 467 is Prime
# 468 is Not prime
# 469 is Not prime
# 470 is Not prime
# 471 is Not prime
# 472 is Not prime
# 473 is Not prime
# 474 is Not prime
# 475 is Not prime
# 476 is Not prime
# 477 is Not prime
# 478 is Not prime
# 479 is Prime
# 480 is Not prime
# 481 is Not prime
# 482 is Not prime
# 483 is Not prime
# 484 is Not prime
# 485 is Not prime
# 486 is Not prime
# 487 is Prime
# 488 is Not prime
# 489 is Not prime
# 490 is Not prime
# 491 is Prime
# 492 is Not prime
# 493 is Not prime
# 494 is Not prime
# 495 is Not prime
# 496 is Not prime
# 497 is Not prime
# 498 is Not prime
# 499 is Prime
# 500 is Not prime
# 501 is Not prime
# 502 is Not prime
# 503 is Prime
# 504 is Not prime
# 505 is Not prime
# 506 is Not prime
# 507 is Not prime
# 508 is Not prime
# 509 is Prime
# 510 is Not prime
# 511 is Not prime
# 512 is Not prime
# 513 is Not prime
# 514 is Not prime
# 515 is Not prime
# 516 is Not prime
# 517 is Not prime
# 518 is Not prime
# 519 is Not prime
# 520 is Not prime
# 521 is Prime
# 522 is Not prime
# 523 is Prime
# 524 is Not prime
# 525 is Not prime
# 526 is Not prime
# 527 is Not prime
# 528 is Not prime
# 529 is Not prime
# 530 is Not prime
# 531 is Not prime
# 532 is Not prime
# 533 is Not prime
# 534 is Not prime
# 535 is Not prime
# 536 is Not prime
# 537 is Not prime
# 538 is Not prime
# 539 is Not prime
# 540 is Not prime
# 541 is Prime
# 542 is Not prime
# 543 is Not prime
# 544 is Not prime
# 545 is Not prime
# 546 is Not prime
# 547 is Prime
# 548 is Not prime
# 549 is Not prime
# 550 is Not prime
# 551 is Not prime
# 552 is Not prime
# 553 is Not prime
# 554 is Not prime
# 555 is Not prime
# 556 is Not prime
# 557 is Prime
# 558 is Not prime
# 559 is Not prime
# 560 is Not prime
# 561 is Not prime
# 562 is Not prime
# 563 is Prime
# 564 is Not prime
# 565 is Not prime
# 566 is Not prime
# 567 is Not prime
# 568 is Not prime
# 569 is Prime
# 570 is Not prime
# 571 is Prime
# 572 is Not prime
# 573 is Not prime
# 574 is Not prime
# 575 is Not prime
# 576 is Not prime
# 577 is Prime
# 578 is Not prime
# 579 is Not prime
# 580 is Not prime
# 581 is Not prime
# 582 is Not prime
# 583 is Not prime
# 584 is Not prime
# 585 is Not prime
# 586 is Not prime
# 587 is Prime
# 588 is Not prime
# 589 is Not prime
# 590 is Not prime
# 591 is Not prime
# 592 is Not prime
# 593 is Prime
# 594 is Not prime
# 595 is Not prime
# 596 is Not prime
# 597 is Not prime
# 598 is Not prime
# 599 is Prime
# 600 is Not prime
# 601 is Prime
# 602 is Not prime
# 603 is Not prime
# 604 is Not prime
# 605 is Not prime
# 606 is Not prime
# 607 is Prime
# 608 is Not prime
# 609 is Not prime
# 610 is Not prime
# 611 is Not prime
# 612 is Not prime
# 613 is Prime
# 614 is Not prime
# 615 is Not prime
# 616 is Not prime
# 617 is Prime
# 618 is Not prime
# 619 is Prime
# 620 is Not prime
# 621 is Not prime
# 622 is Not prime
# 623 is Not prime
# 624 is Not prime
# 625 is Not prime
# 626 is Not prime
# 627 is Not prime
# 628 is Not prime
# 629 is Not prime
# 630 is Not prime
# 631 is Prime
# 632 is Not prime
# 633 is Not prime
# 634 is Not prime
# 635 is Not prime
# 636 is Not prime
# 637 is Not prime
# 638 is Not prime
# 639 is Not prime
# 640 is Not prime
# 641 is Prime
# 642 is Not prime
# 643 is Prime
# 644 is Not prime
# 645 is Not prime
# 646 is Not prime
# 647 is Prime
# 648 is Not prime
# 649 is Not prime
# 650 is Not prime
# 651 is Not prime
# 652 is Not prime
# 653 is Prime
# 654 is Not prime
# 655 is Not prime
# 656 is Not prime
# 657 is Not prime
# 658 is Not prime
# 659 is Prime
# 660 is Not prime
# 661 is Prime
# 662 is Not prime
# 663 is Not prime
# 664 is Not prime
# 665 is Not prime
# 666 is Not prime
# 667 is Not prime
# 668 is Not prime
# 669 is Not prime
# 670 is Not prime
# 671 is Not prime
# 672 is Not prime
# 673 is Prime
# 674 is Not prime
# 675 is Not prime
# 676 is Not prime
# 677 is Prime
# 678 is Not prime
# 679 is Not prime
# 680 is Not prime
# 681 is Not prime
# 682 is Not prime
# 683 is Prime
# 684 is Not prime
# 685 is Not prime
# 686 is Not prime
# 687 is Not prime
# 688 is Not prime
# 689 is Not prime
# 690 is Not prime
# 691 is Prime
# 692 is Not prime
# 693 is Not prime
# 694 is Not prime
# 695 is Not prime
# 696 is Not prime
# 697 is Not prime
# 698 is Not prime
# 699 is Not prime
# 700 is Not prime
# 701 is Prime
# 702 is Not prime
# 703 is Not prime
# 704 is Not prime
# 705 is Not prime
# 706 is Not prime
# 707 is Not prime
# 708 is Not prime
# 709 is Prime
# 710 is Not prime
# 711 is Not prime
# 712 is Not prime
# 713 is Not prime
# 714 is Not prime
# 715 is Not prime
# 716 is Not prime
# 717 is Not prime
# 718 is Not prime
# 719 is Prime
# 720 is Not prime
# 721 is Not prime
# 722 is Not prime
# 723 is Not prime
# 724 is Not prime
# 725 is Not prime
# 726 is Not prime
# 727 is Prime
# 728 is Not prime
# 729 is Not prime
# 730 is Not prime
# 731 is Not prime
# 732 is Not prime
# 733 is Prime
# 734 is Not prime
# 735 is Not prime
# 736 is Not prime
# 737 is Not prime
# 738 is Not prime
# 739 is Prime
# 740 is Not prime
# 741 is Not prime
# 742 is Not prime
# 743 is Prime
# 744 is Not prime
# 745 is Not prime
# 746 is Not prime
# 747 is Not prime
# 748 is Not prime
# 749 is Not prime
# 750 is Not prime
# 751 is Prime
# 752 is Not prime
# 753 is Not prime
# 754 is Not prime
# 755 is Not prime
# 756 is Not prime
# 757 is Prime
# 758 is Not prime
# 759 is Not prime
# 760 is Not prime
# 761 is Prime
# 762 is Not prime
# 763 is Not prime
# 764 is Not prime
# 765 is Not prime
# 766 is Not prime
# 767 is Not prime
# 768 is Not prime
# 769 is Prime
# 770 is Not prime
# 771 is Not prime
# 772 is Not prime
# 773 is Prime
# 774 is Not prime
# 775 is Not prime
# 776 is Not prime
# 777 is Not prime
# 778 is Not prime
# 779 is Not prime
# 780 is Not prime
# 781 is Not prime
# 782 is Not prime
# 783 is Not prime
# 784 is Not prime
# 785 is Not prime
# 786 is Not prime
# 787 is Prime
# 788 is Not prime
# 789 is Not prime
# 790 is Not prime
# 791 is Not prime
# 792 is Not prime
# 793 is Not prime
# 794 is Not prime
# 795 is Not prime
# 796 is Not prime
# 797 is Prime
# 798 is Not prime
# 799 is Not prime
# 800 is Not prime
# 801 is Not prime
# 802 is Not prime
# 803 is Not prime
# 804 is Not prime
# 805 is Not prime
# 806 is Not prime
# 807 is Not prime
# 808 is Not prime
# 809 is Prime
# 810 is Not prime
# 811 is Prime
# 812 is Not prime
# 813 is Not prime
# 814 is Not prime
# 815 is Not prime
# 816 is Not prime
# 817 is Not prime
# 818 is Not prime
# 819 is Not prime
# 820 is Not prime
# 821 is Prime
# 822 is Not prime
# 823 is Prime
# 824 is Not prime
# 825 is Not prime
# 826 is Not prime
# 827 is Prime
# 828 is Not prime
# 829 is Prime
# 830 is Not prime
# 831 is Not prime
# 832 is Not prime
# 833 is Not prime
# 834 is Not prime
# 835 is Not prime
# 836 is Not prime
# 837 is Not prime
# 838 is Not prime
# 839 is Prime
# 840 is Not prime
# 841 is Not prime
# 842 is Not prime
# 843 is Not prime
# 844 is Not prime
# 845 is Not prime
# 846 is Not prime
# 847 is Not prime
# 848 is Not prime
# 849 is Not prime
# 850 is Not prime
# 851 is Not prime
# 852 is Not prime
# 853 is Prime
# 854 is Not prime
# 855 is Not prime
# 856 is Not prime
# 857 is Prime
# 858 is Not prime
# 859 is Prime
# 860 is Not prime
# 861 is Not prime
# 862 is Not prime
# 863 is Prime
# 864 is Not prime
# 865 is Not prime
# 866 is Not prime
# 867 is Not prime
# 868 is Not prime
# 869 is Not prime
# 870 is Not prime
# 871 is Not prime
# 872 is Not prime
# 873 is Not prime
# 874 is Not prime
# 875 is Not prime
# 876 is Not prime
# 877 is Prime
# 878 is Not prime
# 879 is Not prime
# 880 is Not prime
# 881 is Prime
# 882 is Not prime
# 883 is Prime
# 884 is Not prime
# 885 is Not prime
# 886 is Not prime
# 887 is Prime
# 888 is Not prime
# 889 is Not prime
# 890 is Not prime
# 891 is Not prime
# 892 is Not prime
# 893 is Not prime
# 894 is Not prime
# 895 is Not prime
# 896 is Not prime
# 897 is Not prime
# 898 is Not prime
# 899 is Not prime
# 900 is Not prime
# 901 is Not prime
# 902 is Not prime
# 903 is Not prime
# 904 is Not prime
# 905 is Not prime
# 906 is Not prime
# 907 is Prime
# 908 is Not prime
# 909 is Not prime
# 910 is Not prime
# 911 is Prime
# 912 is Not prime
# 913 is Not prime
# 914 is Not prime
# 915 is Not prime
# 916 is Not prime
# 917 is Not prime
# 918 is Not prime
# 919 is Prime
# 920 is Not prime
# 921 is Not prime
# 922 is Not prime
# 923 is Not prime
# 924 is Not prime
# 925 is Not prime
# 926 is Not prime
# 927 is Not prime
# 928 is Not prime
# 929 is Prime
# 930 is Not prime
# 931 is Not prime
# 932 is Not prime
# 933 is Not prime
# 934 is Not prime
# 935 is Not prime
# 936 is Not prime
# 937 is Prime
# 938 is Not prime
# 939 is Not prime
# 940 is Not prime
# 941 is Prime
# 942 is Not prime
# 943 is Not prime
# 944 is Not prime
# 945 is Not prime
# 946 is Not prime
# 947 is Prime
# 948 is Not prime
# 949 is Not prime
# 950 is Not prime
# 951 is Not prime
# 952 is Not prime
# 953 is Prime
# 954 is Not prime
# 955 is Not prime
# 956 is Not prime
# 957 is Not prime
# 958 is Not prime
# 959 is Not prime
# 960 is Not prime
# 961 is Not prime
# 962 is Not prime
# 963 is Not prime
# 964 is Not prime
# 965 is Not prime
# 966 is Not prime
# 967 is Prime
# 968 is Not prime
# 969 is Not prime
# 970 is Not prime
# 971 is Prime
# 972 is Not prime
# 973 is Not prime
# 974 is Not prime
# 975 is Not prime
# 976 is Not prime
# 977 is Prime
# 978 is Not prime
# 979 is Not prime
# 980 is Not prime
# 981 is Not prime
# 982 is Not prime
# 983 is Prime
# 984 is Not prime
# 985 is Not prime
# 986 is Not prime
# 987 is Not prime
# 988 is Not prime
# 989 is Not prime
# 990 is Not prime
# 991 is Prime
# 992 is Not prime
# 993 is Not prime
# 994 is Not prime
# 995 is Not prime
# 996 is Not prime
# 997 is Prime
# 998 is Not prime
# 999 is Not prime
